# %%
import yfinance as yf
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

from time import sleep

import mysql.connector

pd.options.mode.chained_assignment = None  # default='warn' maybe disable idk

# %%
#Stock Historical Data Constants
# ticker = 'ETC-USD'
ticker = 'MSFT'

period = 'max' # max, y, mo, d, h
interval = '1d'

stock = yf.Ticker(ticker)
history = stock.history(period=period, interval = interval)

# %%
options_dates = stock.options

# %%
# for date in options_dates:
#     print(stock.option_chain(date).calls)
#     print(stock.option_chain(date).puts)

# %%
options_dates
# Out:
# ('2021-02-26',
#  '2021-03-05',
#  '2021-03-12',
#  '2021-03-19',
#  '2021-03-26',
#  '2021-04-01',
#  '2021-04-16',
#  '2021-05-21',
#  '2021-06-18',
#  '2021-07-16',
#  '2021-08-20',
#  '2021-09-17',
#  '2021-10-15',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17')

# %%
option1_call = stock.option_chain(options_dates[0]).calls

# %%
option1_call
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice  bid  ask  \
# 0   MSFT210226C00170000 2021-02-19 17:20:14   170.0      71.45  0.0  0.0
# 1   MSFT210226C00175000 2021-01-28 20:39:10   175.0      59.39  0.0  0.0
# 2   MSFT210226C00180000 2021-02-17 16:13:53   180.0      48.25  0.0  0.0
# 3   MSFT210226C00185000 2021-02-23 19:06:11   185.0      47.42  0.0  0.0
# 4   MSFT210226C00190000 2021-02-17 19:59:26   190.0      53.40  0.0  0.0
# 5   MSFT210226C00192500 2021-02-11 17:09:16   192.5      50.98  0.0  0.0
# 6   MSFT210226C00195000 2021-02-22 16:05:12   195.0      39.35  0.0  0.0
# 7   MSFT210226C00197500 2021-02-19 19:45:52   197.5      37.01  0.0  0.0
# 8   MSFT210226C00200000 2021-02-22 15:36:15   200.0      31.42  0.0  0.0
# 9   MSFT210226C00202500 2021-02-22 18:44:04   202.5      32.70  0.0  0.0
# 10  MSFT210226C00205000 2021-02-22 15:47:21   205.0      29.15  0.0  0.0
# 11  MSFT210226C00207500 2021-02-16 20:30:45   207.5      35.65  0.0  0.0
# ...

# %%
option1_call.describe()
# Out:
#            strike  lastPrice   bid   ask  change  percentChange        volume  \
# count   49.000000  49.000000  49.0  49.0    49.0           49.0     49.000000
# mean   243.469388  13.446939   0.0   0.0     0.0            0.0   1179.510204
# std     42.722507  19.706529   0.0   0.0     0.0            0.0   2945.176502
# min    170.000000   0.010000   0.0   0.0     0.0            0.0      1.000000
# 25%    210.000000   0.020000   0.0   0.0     0.0            0.0      3.000000
# 50%    240.000000   0.310000   0.0   0.0     0.0            0.0     23.000000
# 75%    270.000000  20.150000   0.0   0.0     0.0            0.0    251.000000
# max    330.000000  71.450000   0.0   0.0     0.0            0.0  15630.000000
#
#        openInterest  impliedVolatility
# count          49.0          49.000000
# mean            0.0           0.176666
# std             0.0           0.206259
# min             0.0           0.000010
# 25%             0.0           0.000010
# ...

# %%
stock.balance_sheet
# Out:
#                                     2020-06-30    2019-06-30    2018-06-30  \
# Intangible Assets                 7.038000e+09  7.750000e+09  8.053000e+09
# Total Liab                        1.830070e+11  1.842260e+11  1.761300e+11
# Total Stockholder Equity          1.183040e+11  1.023300e+11  8.271800e+10
# Other Current Liab                4.600100e+10  4.586000e+10  3.819500e+10
# Total Assets                      3.013110e+11  2.865560e+11  2.588480e+11
# Common Stock                      8.055200e+10  7.852000e+10  7.122300e+10
# Other Current Assets              1.151700e+10  1.013300e+10  6.855000e+09
# Retained Earnings                 3.456600e+10  2.415000e+10  1.368200e+10
# Other Liab                        3.449200e+10  3.569900e+10  3.570700e+10
# Good Will                         4.335100e+10  4.202600e+10  3.568300e+10
# Treasury Stock                    3.186000e+09 -3.400000e+08 -2.187000e+09
# ...

# %%
stock.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  614100233    2020-12-30  0.0814
# 1                     Blackrock Inc.  515509179    2020-12-30  0.0683
# 2           State Street Corporation  299126371    2020-12-30  0.0397
# 3                           FMR, LLC  222257473    2020-12-30  0.0295
# 4      Price (T.Rowe) Associates Inc  177500157    2020-12-30  0.0235
# 5      Geode Capital Management, LLC  117798162    2020-12-30  0.0156
# 6            Capital World Investors  110441260    2020-12-30  0.0146
# 7  Capital Research Global Investors   95506129    2020-12-30  0.0127
# 8    Capital International Investors   91995988    2020-12-30  0.0122
# 9         Northern Trust Corporation   91215100    2020-12-30  0.0121
#
#           Value
# 0  136588173823
# 1  114659551593
# 2   66531687437
# 3   49434507144
# 4   39479584919
# 5   26200667192
# 6   24564345049
# 7   21242473212
# 8   20461747650
# 9   20288062542
