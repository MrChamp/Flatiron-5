# %%
import pandas as pd
import numpy as np

# %%
amex = pd.read_csv('/home/steve/documents/finance/obtain/amex.csv')
nasdaq = pd.read_csv('/home/steve/documents/finance/obtain/nasdaq.csv')
nyse = pd.read_csv('/home/steve/documents/finance/obtain/nyse.csv')

# %%
exch =  [amex, nasdaq, nyse]

# %%
exchanges = pd.concat(exch)

# %%
exchanges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7580 entries, 0 to 3273
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         7580 non-null   object
#  1   Name           7580 non-null   object
#  2   LastSale       7242 non-null   float64
#  3   MarketCap      5640 non-null   object
#  4   IPOyear        3664 non-null   float64
#  5   Sector         5741 non-null   object
#  6   industry       5741 non-null   object
#  7   Summary Quote  7580 non-null   object
#  8   Unnamed: 8     0 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 592.2+ KB

# %%
exchanges.head()
# Out:
#   Symbol                                               Name  LastSale  \
# 0   GOED                                 1847 Goedeker Inc.      9.32
# 1   XXII                            22nd Century Group, Inc      2.78
# 2    FAX              Aberdeen Asia-Pacific Income Fund Inc      4.35
# 3    IAF                 Aberdeen Australia Equity Fund Inc      5.41
# 4    AEF  Aberdeen Emerging Markets Equity Income Fund, ...      8.47
#
#   MarketCap  IPOyear                 Sector               industry  \
# 0   $56.96M   2020.0      Consumer Services       Home Furnishings
# 1  $386.03M      NaN  Consumer Non-Durables  Farming/Seeds/Milling
# 2    $1.08B   1986.0                    NaN                    NaN
# 3  $125.11M      NaN                    NaN                    NaN
# 4  $429.87M      NaN                    NaN                    NaN
#
#                         Summary Quote  Unnamed: 8
# 0  https://old.nasdaq.com/symbol/goed         NaN
# ...

# %%
exchanges.tail()
# Out:
#      Symbol                          Name  LastSale MarketCap  IPOyear  \
# 3269    ZBH  Zimmer Biomet Holdings, Inc.    160.12   $33.19B      NaN
# 3270    ZTS                   Zoetis Inc.    161.56   $76.78B   2013.0
# 3271    ZTO     ZTO Express (Cayman) Inc.     29.52   $25.25B   2016.0
# 3272    ZUO                   Zuora, Inc.     13.41     $1.6B   2018.0
# 3273   ZYME                Zymeworks Inc.     54.68    $2.51B   2017.0
#
#               Sector                                 industry  \
# 3269     Health Care                   Industrial Specialties
# 3270     Health Care                    Major Pharmaceuticals
# 3271  Transportation        Trucking Freight/Courier Services
# 3272      Technology  Computer Software: Prepackaged Software
# 3273     Health Care                    Major Pharmaceuticals
#
#                            Summary Quote  Unnamed: 8
# 3269   https://old.nasdaq.com/symbol/zbh         NaN
# 3270   https://old.nasdaq.com/symbol/zts         NaN
# ...

# %%
exchanges['Symbol'] = exchanges['Symbol'].str.replace('^','-')
exchanges['Symbol'] = exchanges['Symbol'].str.replace('.','-')

# %%
pared_symbols = pd.read_csv('/home/steve/documents/flatIron/fIProject/Stocks/master_list_no_empty.csv')
pared_array = np.array(pared_symbols['ticker'])

# %%
exchanges = exchanges[exchanges['Symbol'].isin(pared_array)]

# %%
exchanges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6587 entries, 0 to 3273
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         6587 non-null   object
#  1   Name           6587 non-null   object
#  2   LastSale       6544 non-null   float64
#  3   MarketCap      5626 non-null   object
#  4   IPOyear        3391 non-null   float64
#  5   Sector         5504 non-null   object
#  6   industry       5504 non-null   object
#  7   Summary Quote  6587 non-null   object
#  8   Unnamed: 8     0 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 514.6+ KB

# %%
# exchanges.to_csv('/home/steve/documents/finance/fIProject/Stocks/combined_pared_df.csv',index=False)

# %%
for sector in exchanges['industry'].unique():
    print(sector,':', len(exchanges.loc[exchanges['industry'] == sector]))
# Out:
# Home Furnishings : 28
# Farming/Seeds/Milling : 31
# nan : 0
# Industrial Machinery/Components : 167
# Major Pharmaceuticals : 540
# Oil Refining/Marketing : 16
# Diversified Commercial Services : 36
# Aerospace : 16
# Military/Government/Technical : 32
# Precious Metals : 90
# Industrial Specialties : 46
# Real Estate : 69
# Other Consumer Services : 81
# Food Distributors : 15
# Medical Specialities : 47
# Biotechnology: Biological Products (No Diagnostic Substances) : 153
# Professional Services : 42
# Environmental Services : 13
# Major Banks : 354
# Oil & Gas Production : 123
# Agricultural Chemicals : 14
# Consumer Specialties : 11
# Radio And Television Broadcasting And Communications Equipment : 30
# Real Estate Investment Trusts : 235
# Package Goods/Cosmetics : 17
# Mining & Quarrying of Nonmetallic Minerals (No Fuels) : 17
# Business Services : 456
# Building Products : 11
# Oil/Gas Transmission : 14
# Investment Bankers/Brokers/Service : 50
# Plastic Products : 12
# ...
